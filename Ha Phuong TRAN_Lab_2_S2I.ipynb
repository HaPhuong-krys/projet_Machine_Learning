# %% [markdown]
# ---
# University Paris 1 Panthéon-Sorbonne
#
# Introduction to Machine Learning
#
# Dr. Nourhène BEN RABAH
#
# ---
#
# # Lab 2: Mise à l'échelle, normalisation et transformation des données
#
# #### Vous devez envoyer le notebook complété pendant la session sur Discord.
#
# ---

# %% [markdown]
# ##### Exercice1.
#
# Vous appliquerez l'encodage des étiquettes pour la colonne "vote" et l'encodage à chaud pour la colonne "region".

# %%
import pandas as pnd

dfCategories = pnd.DataFrame (
    [ ['male', 'from US', 'uses Safari', 'approves'], 
      ['female', 'from Europe', 'uses Firefox', 'disaproves'] ,
      ['female', 'from US', 'uses Safari', 'approves'],
      ['male', 'from Europe', 'uses Safari', 'approves'],
      ['female', 'from US', 'uses Firefox', 'disaproves'] ,
      ['male', 'from Europe', 'uses Chrome', 'disaproves'] , 
      ['female', 'from Asia', 'uses Chrome', 'approves'],
      ['male', 'from Asia', 'uses Chrome', 'approves'] ],
    columns=['sex', 'region','browser', 'vote' ])

dfCategories
# Out:
#       sex       region       browser        vote
# 0    male      from US   uses Safari    approves
# 1  female  from Europe  uses Firefox  disaproves
# 2  female      from US   uses Safari    approves
# 3    male  from Europe   uses Safari    approves
# 4  female      from US  uses Firefox  disaproves
# 5    male  from Europe   uses Chrome  disaproves
# 6  female    from Asia   uses Chrome    approves
# 7    male    from Asia   uses Chrome    approves

# %%
from sklearn.preprocessing import LabelEncoder

label_encode_vote = LabelEncoder()

encoded_vote = label_encode_vote.fit_transform(dfCategories['vote'])

print("Encoded Vote:", encoded_vote)
# Out:
# Encoded Vote: [0 1 0 0 1 1 0 0]

# %%
one_hot_region = pnd.get_dummies(dfCategories['region'])

print("One-Hot Encoded Data:")
print(one_hot_region)
# Out:
# One-Hot Encoded Data:
#    from Asia  from Europe  from US
# 0      False        False     True
# 1      False         True    False
# 2      False        False     True
# 3      False         True    False
# 4      False        False     True
# 5      False         True    False
# 6       True        False    False
# 7       True        False    False

# %% [markdown]
# ##### Exercice2. Détection d'attaques IoT avec Danmini.csv
#
# Dans cet exercice, vous allez importer le Dataset Danmini (Danmini. csv) qui contient des données pour prédire si l'attaque IoT est bashlite ou Mirai sur un appareil Danmini Doorbel.
#
# - 1) Commencez par découvrir le jeu de données (nombre de lignes, colonnes, types de colonnes, valeur cible à prédire, voir les premières lignes et les dernières lignes, ... (comme nous l'avons fait dans le premier laboratoire).
# - 2) Nettoyage des données (voir les valeurs manquantes et effectuer le nettoyage des données)
# - 3) Mise à l'échelle des données, normalisation
# - 4) Transformation des données (encodage des valeurs numériques).
#
# Après ces étapes, vous pouvez entraîner votre premier algo ML, que nous découvrirons dans la prochaine session.

# %%
import pandas as pd
import numpy as np

# %%
df_dam = pd.read_csv(r"C:\Users\haphu\Documents\M2 MIAGE\Machine Learning\Datasets\Danmini.csv", sep = ",")

df_dam
# Out:
#          MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 0                1.000000       98.000000        0.000000e+00
# 1                1.029000       98.000000        1.818989e-12
# 2                1.504156       76.725612        2.281808e+02
# 3                2.460087       75.617679        1.372200e+02
# 4                3.460055       75.150149        9.809937e+01
# ...                   ...             ...                 ...
# 1018293        113.491749      482.411866        3.023968e+04
# 1018294        114.274393      483.038324        3.001951e+04
# 1018295        112.510015      483.669039        2.979705e+04
# 1018296        111.577847      484.299369        2.957393e+04
# 1018297        111.273486      484.925760        2.935142e+04
#
#          MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 0                1.000000       98.000000            0.000000
# 1                1.119520       98.000000            0.000000
# ...

# %%
df_dam.dtypes
# Out:
# MI_dir_L5_weight         float64
# MI_dir_L5_mean           float64
# MI_dir_L5_variance       float64
# MI_dir_L3_weight         float64
# MI_dir_L3_mean           float64
#                           ...
# HpHp_L0.01_magnitude     float64
# HpHp_L0.01_radius        float64
# HpHp_L0.01_covariance    float64
# HpHp_L0.01_pcc           float64
# Label                     object
# Length: 116, dtype: object

# %%
df_dam.shape
# Out:
# (1018298, 116)

# %%
df_dam.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       98.000000        0.000000e+00          1.000000
# 1          1.029000       98.000000        1.818989e-12          1.119520
# 2          1.504156       76.725612        2.281808e+02          1.729662
# 3          2.460087       75.617679        1.372200e+02          2.699075
# 4          3.460055       75.150149        9.809937e+01          3.699054
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       98.000000            0.000000          1.000000       98.000000
# 1       98.000000            0.000000          1.492583       98.000000
# 2       79.499272          249.746357          2.294102       84.051188
# 3       77.461807          164.269331          3.280499       80.987267
# 4       76.525944          122.224798          4.280490       79.354915
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  \
# ...

# %%
df_dam.tail()
# Out:
#          MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 1018293        113.491749      482.411866        30239.677274
# 1018294        114.274393      483.038324        30019.508409
# 1018295        112.510015      483.669039        29797.050830
# 1018296        111.577847      484.299369        29573.933616
# 1018297        111.273486      484.925760        29351.424045
#
#          MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 1018293        199.109574      442.139363        42746.352594
# 1018294        199.880689      442.699000        42594.781415
# 1018295        197.965340      443.261225        42441.878665
# 1018296        196.918447      443.823583        42288.307084
# 1018297        196.533996      444.384180        42134.586967
#
#          MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 1018293        630.092572      399.949753        52369.148929
# 1018294        630.851040      400.193947        52323.694001
# ...

# %%
## Les lables existé dans le data set

set(df_dam['Label'].values)
# Out:
# {'DanminiBash', 'DanminiMirai', 'N'}

# %%
df_dam.describe()
# Out:
#        MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# count      1.018298e+06    1.018298e+06        1.018298e+06      1.018298e+06
# mean       9.479704e+01    1.927187e+02        1.970133e+04      1.502972e+02
# std        6.380090e+01    1.631548e+02        2.517558e+04      1.010881e+02
# min        1.000000e+00    6.000000e+01        0.000000e+00      1.000000e+00
# 25%        1.124271e+01    6.000000e+01        3.755417e-09      2.661462e+01
# 50%        1.108011e+02    7.407356e+01        3.869695e+01      1.870080e+02
# 75%        1.471055e+02    3.308499e+02        4.867314e+04      2.311400e+02
# max        3.416813e+02    8.861669e+02        1.738886e+05      4.704900e+02
#
#        MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# count    1.018298e+06        1.018298e+06      1.018298e+06    1.018298e+06
# mean     1.934838e+02        2.200175e+04      4.328257e+02    1.947330e+02
# ...

# %%
df_dam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018298 entries, 0 to 1018297
# Columns: 116 entries, MI_dir_L5_weight to Label
# dtypes: float64(115), object(1)
# memory usage: 901.2+ MB

# %% [markdown]
# ## Nettoyage de données - Voir les données manquantes

# %%
## Détecter si ya les lignes contenant que des valeur null
ligne_null = df_dam[df_dam.isnull().any(axis = 1)]
ligne_null
# Out:
# Empty DataFrame
# ...

# %%
colonne_null = df_dam.columns[df_dam.isnull().any()]
print(colonne_null)
# Out:
# Index([], dtype='object')

# %% [markdown]
# => Il n'y a pas de valeur null

# %% [markdown]
# ## Mis à l'échelle

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data_scaler = MinMaxScaler(feature_range = (0, 1))

df_dam_scal = data_scaler.fit_transform(df_dam.iloc[:,:-1])

df_dam_scal
# Out:
# array([[0.00000000e+00, 4.59955516e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 7.39219950e-03, 2.61200068e-01],
#        [8.51237588e-05, 4.59955516e-02, 1.04606614e-17, ...,
#         3.79454966e-18, 7.39219950e-03, 2.61200068e-01],
#        [1.47984680e-03, 2.02448358e-02, 1.31222448e-03, ...,
#         0.00000000e+00, 7.39219950e-03, 2.61200068e-01],
#        ...,
#        [3.27314774e-01, 5.12812924e-01, 1.71357160e-01, ...,
#         0.00000000e+00, 7.39219950e-03, 2.61200068e-01],
#        [3.24578587e-01, 5.13575883e-01, 1.70074055e-01, ...,
#         0.00000000e+00, 7.39219950e-03, 2.61200068e-01],
#        [3.23685196e-01, 5.14334071e-01, 1.68794445e-01, ...,
#         0.00000000e+00, 7.39219950e-03, 2.61200068e-01]])

# %% [markdown]
# ## Normalisation

# %%
from sklearn.preprocessing import Normalizer

normal1 = Normalizer(norm = 'l2')

data_norm = normal1.transform(df_dam.iloc[:,:-1].values)

data_norm
# Out:
# array([[2.96971474e-10, 2.91032044e-08, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.05903145e-18, 1.00860132e-16, 1.87207664e-30, ...,
#         1.87207664e-30, 0.00000000e+00, 0.00000000e+00],
#        [4.46691452e-10, 2.27853181e-08, 6.77631985e-08, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [9.48831241e-11, 4.07892839e-10, 2.51287610e-08, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [9.40992908e-11, 4.08434365e-10, 2.49412070e-08, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [9.38448930e-11, 4.08972594e-10, 2.47541562e-08, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %% [markdown]
# ## Transformation données

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()

data_trans = label.fit_transform(df_dam['Label'])

print(data_trans)
# Out:
# [0 0 0 ... 1 1 1]

# %% [markdown]
# ##### Projet
#
# Passons à la phase 1. Préparation des données :
# Vous préparerez les données en effectuant des opérations telles que le nettoyage, la normalisation et la transformation des données. Pour ce faire, vous devrez :
# - Décrire vos données (nombre de lignes, de colonnes, types de colonnes, valeur cible à prédire, voir les premières lignes et les dernières lignes, ...) (comme nous l'avons fait dans le premier laboratoire).
# - Décrire la ou les techniques de nettoyage des données utilisées (justifiez les décisions prises).
# - Décrire les méthodes de normalisation, de mise à l'échelle et de transformation des données utilisées et justifiez les décisions prises.
# - Le code doit être commenté et expliqué.
